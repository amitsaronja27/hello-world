# %% [markdown]
# <a href="https://colab.research.google.com/github/amitsaronja27/hello-world/blob/master/Untitled2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd                                 # Importing pandas
import numpy as np                                  # Importing numpy
import matplotlib.pyplot as plt                     # Importing matplotlib for visualization

# %matplotlib inline                      
import seaborn as sns                               # Importing seaborn for visualization

import matplotlib.ticker as ticker
import matplotlib.cm as cm

import pandas_profiling                             # AUtomatic EDA

import ipywidgets as widgets                        # Creating widgets
from IPython.display import display                 # Displaying widgets

# %%
zomato_df = pd.read_csv('zomato.csv',encoding = "ISO-8859-1")    # Reading file zomato.csv

# %%
zomato_df[['City','Locality']][:200]
# Out:
#                        City                                           Locality
# 0               Makati City          Century City Mall, Poblacion, Makati City
# 1               Makati City         Little Tokyo, Legaspi Village, Makati City
# 2          Mandaluyong City         Edsa Shangri-La, Ortigas, Mandaluyong City
# 3          Mandaluyong City             SM Megamall, Ortigas, Mandaluyong City
# 4          Mandaluyong City             SM Megamall, Ortigas, Mandaluyong City
# 5          Mandaluyong City             SM Megamall, Ortigas, Mandaluyong City
# 6                Pasay City    SM by the Bay, Mall of Asia Complex, Pasay City
# 7                Pasay City    SM by the Bay, Mall of Asia Complex, Pasay City
# 8                Pasay City        Sofitel Philippine Plaza Manila, Pasay City
# 9                Pasig City                                          Kapitolyo
# 10               Pasig City                                          Kapitolyo
# 11               Pasig City                                          Kapitolyo
# 12              Quezon City               UP Town Center, Diliman, Quezon City
# 13            San Juan City                                     Addition Hills
# 14            San Juan City                                      Little Baguio
# 15               Santa Rosa                       Nuvali, Don Jose, Santa Rosa
# 16               Santa Rosa                    Solenad 3, Don Jose, Santa Rosa
# 17            Tagaytay City                                      Tagaytay City
# 18              Taguig City      BGC Stopover Pavillion, Bonifacio Global City
# 19              Taguig City                              Bonifacio Global City
# 20              Taguig City  SM Aura Premier, Bonifacio Global City, Taguig...
# 21              Taguig City  SM Aura Premier, Bonifacio Global City, Taguig...
# 22                Brasí_lia                                          Asa Norte
# 23                Brasí_lia                                          Asa Norte
# 24                Brasí_lia                                          Asa Norte
# 25                Brasí_lia                                          Asa Norte
# 26                Brasí_lia                                            Asa Sul
# 27                Brasí_lia                                            Asa Sul
# 28                Brasí_lia                                            Asa Sul
# 29                Brasí_lia                                            Asa Sul
# ..                      ...                                                ...
# 170  Cedar Rapids/Iowa City                                       Cedar Rapids
# 171  Cedar Rapids/Iowa City                                       Cedar Rapids
# 172  Cedar Rapids/Iowa City                                       Cedar Rapids
# 173  Cedar Rapids/Iowa City                                         Coralville
# 174  Cedar Rapids/Iowa City                                         Coralville
# 175  Cedar Rapids/Iowa City                                          Iowa City
# 176  Cedar Rapids/Iowa City                                          Iowa City
# 177  Cedar Rapids/Iowa City                                          Iowa City
# 178  Cedar Rapids/Iowa City                                          Iowa City
# 179  Cedar Rapids/Iowa City                                          Iowa City
# 180  Cedar Rapids/Iowa City                                          Iowa City
# 181  Cedar Rapids/Iowa City                                          Iowa City
# 182  Cedar Rapids/Iowa City                                          Iowa City
# 183  Cedar Rapids/Iowa City                                          Iowa City
# 184  Cedar Rapids/Iowa City                                             Marion
# 185            Chatham-Kent                                       Chatham-Kent
# 186              Clatskanie                                         Clatskanie
# 187                Cochrane                                           Cochrane
# 188                Columbus                                           Columbus
# 189                Columbus                                           Columbus
# 190                Columbus                                           Columbus
# 191                Columbus                                           Columbus
# 192                Columbus                                           Columbus
# 193                Columbus                                           Columbus
# 194                Columbus                                           Columbus
# 195                Columbus                                           Columbus
# 196                Columbus                                           Columbus
# 197                Columbus                                           Columbus
# 198                Columbus                                           Columbus
# 199                Columbus                                           Columbus
#
# [200 rows x 2 columns]

# %%
zomato_df[['City','Locality']][:200]
# Out:
#                        City                                           Locality
# 0               Makati City          Century City Mall, Poblacion, Makati City
# 1               Makati City         Little Tokyo, Legaspi Village, Makati City
# 2          Mandaluyong City         Edsa Shangri-La, Ortigas, Mandaluyong City
# 3          Mandaluyong City             SM Megamall, Ortigas, Mandaluyong City
# 4          Mandaluyong City             SM Megamall, Ortigas, Mandaluyong City
# 5          Mandaluyong City             SM Megamall, Ortigas, Mandaluyong City
# 6                Pasay City    SM by the Bay, Mall of Asia Complex, Pasay City
# 7                Pasay City    SM by the Bay, Mall of Asia Complex, Pasay City
# 8                Pasay City        Sofitel Philippine Plaza Manila, Pasay City
# 9                Pasig City                                          Kapitolyo
# 10               Pasig City                                          Kapitolyo
# 11               Pasig City                                          Kapitolyo
# 12              Quezon City               UP Town Center, Diliman, Quezon City
# 13            San Juan City                                     Addition Hills
# 14            San Juan City                                      Little Baguio
# 15               Santa Rosa                       Nuvali, Don Jose, Santa Rosa
# 16               Santa Rosa                    Solenad 3, Don Jose, Santa Rosa
# 17            Tagaytay City                                      Tagaytay City
# 18              Taguig City      BGC Stopover Pavillion, Bonifacio Global City
# 19              Taguig City                              Bonifacio Global City
# 20              Taguig City  SM Aura Premier, Bonifacio Global City, Taguig...
# 21              Taguig City  SM Aura Premier, Bonifacio Global City, Taguig...
# 22                Brasí_lia                                          Asa Norte
# 23                Brasí_lia                                          Asa Norte
# 24                Brasí_lia                                          Asa Norte
# 25                Brasí_lia                                          Asa Norte
# 26                Brasí_lia                                            Asa Sul
# 27                Brasí_lia                                            Asa Sul
# 28                Brasí_lia                                            Asa Sul
# 29                Brasí_lia                                            Asa Sul
# ..                      ...                                                ...
# 170  Cedar Rapids/Iowa City                                       Cedar Rapids
# 171  Cedar Rapids/Iowa City                                       Cedar Rapids
# 172  Cedar Rapids/Iowa City                                       Cedar Rapids
# 173  Cedar Rapids/Iowa City                                         Coralville
# 174  Cedar Rapids/Iowa City                                         Coralville
# 175  Cedar Rapids/Iowa City                                          Iowa City
# 176  Cedar Rapids/Iowa City                                          Iowa City
# 177  Cedar Rapids/Iowa City                                          Iowa City
# 178  Cedar Rapids/Iowa City                                          Iowa City
# 179  Cedar Rapids/Iowa City                                          Iowa City
# 180  Cedar Rapids/Iowa City                                          Iowa City
# 181  Cedar Rapids/Iowa City                                          Iowa City
# 182  Cedar Rapids/Iowa City                                          Iowa City
# 183  Cedar Rapids/Iowa City                                          Iowa City
# 184  Cedar Rapids/Iowa City                                             Marion
# 185            Chatham-Kent                                       Chatham-Kent
# 186              Clatskanie                                         Clatskanie
# 187                Cochrane                                           Cochrane
# 188                Columbus                                           Columbus
# 189                Columbus                                           Columbus
# 190                Columbus                                           Columbus
# 191                Columbus                                           Columbus
# 192                Columbus                                           Columbus
# 193                Columbus                                           Columbus
# 194                Columbus                                           Columbus
# 195                Columbus                                           Columbus
# 196                Columbus                                           Columbus
# 197                Columbus                                           Columbus
# 198                Columbus                                           Columbus
# 199                Columbus                                           Columbus
#
# [200 rows x 2 columns]

# %%
#venkat
zomato_df[(zomato_df["City"] == 'Makati City') & (zomato_df["Aggregate rating"] > 4)]
# Out:
#    Restaurant ID   Restaurant Name  ...  Rating text Votes
# 0        6317637  Le Petit Souffle  ...    Excellent   314
# 1        6304287  Izakaya Kikufuji  ...    Excellent   591
#
# [2 rows x 21 columns]

# %%
#Venkat
zomato_df[zomato_df["Restaurant Name"].str.match('Dhaba', case=True)]
# Out:
#       Restaurant ID  ... Votes
# 1251         306153  ...  1658
# 4186       18466975  ...    23
# 5035           7332  ...    16
# 5062       18358663  ...     0
# 5581       18361765  ...     0
# 5734       18434072  ...     0
# 5909       18303863  ...    15
# 6670            966  ...   662
# 7484           2682  ...   548
# 8435       18336495  ...   477
#
# [10 rows x 21 columns]

# %%
def evaluatestring(eachvalue):
  if keyword.lower() in eachvalue.lower():
    return 1
  else:
    return 0
  
global keyword
keyword = 'PIZZA'
zomato_df['NewValue'] = zomato_df['Restaurant Name'].apply(evaluatestring)
zomato_df[zomato_df['NewValue'] == 1]['Restaurant Name']
# Out:
# 26                               Pizza íæ Bessa
# 131     Giuseppe's Pizza & Italian Specialities
# 154                         Flying Pie Pizzaria
# 156       Guido's Original New York Style Pizza
# 179                       A & A Pagliai's Pizza
# 217           Tony's Italian Restaurant & Pizza
# 231                      Crust Stone Oven Pizza
# 256                                Fong's Pizza
# 277               Happy Joe's Pizza & Ice Cream
# 324                     Ingleside Village Pizza
# 477                             Bob Roe's Pizza
# 483                               Jerry's Pizza
# 493                              El Fredo Pizza
# 566                              Pizza Di Rocco
# 613                                   Pizza Hut
# 641                                   Pizza Hut
# 648                          Fozzie's Pizzaiolo
# 649                             La Pino'z Pizza
# 674                                   Pizza Hut
# 709                              Domino's Pizza
# 753                                   Pizza Hut
# 933                               Chicago Pizza
# 1052                             Domino's Pizza
# 1076                              Pizza Express
# 1098                               Pizza Street
# 1106                              Da Pizza Zone
# 1130                             Domino's Pizza
# 1192                             Domino's Pizza
# 1194                                  PizzaVito
# 1225                   California Pizza Kitchen
#                          ...
# 8277                         Pizza Hut Delivery
# 8317                             Domino's Pizza
# 8344                                  Pizza Key
# 8371                               Cheese Pizza
# 8437                             Domino's Pizza
# 8510                 Hungry House Pizzas & More
# 8531                         Pizza Hut Delivery
# 8581                              Mexican Pizza
# 8615                             Domino's Pizza
# 8640                            Ovenstory Pizza
# 8655                              Chicago Pizza
# 8715                             Domino's Pizza
# 8749                             Domino's Pizza
# 8752                         Pizza Hut Delivery
# 8861                             Domino's Pizza
# 8878                                  Pizza Hut
# 8987                             Domino's Pizza
# 9039                                  Pizza Hut
# 9051                                   US Pizza
# 9059                                  Pizza Hut
# 9067                             Pizza Junction
# 9068                             Domino's Pizza
# 9078                             Domino's Pizza
# 9094                                  Pizza Hut
# 9192                                  Pizza Hut
# 9210                                  Pizza Hut
# 9234                                  Pizza Hut
# 9256                                  Pizza Hut
# 9257                                  Pizza Hut
# 9536                            Pizza ÛÁl Forno
# Name: Restaurant Name, Length: 253, dtype: object

# %%
S = "I love pizza and burger"
if "pizza".lower() in S.lower():
  print ("Found")
# Out:
# Found

# %%
# !pip install fuzzywuzzy[speedup]
# Out:
# Collecting fuzzywuzzy[speedup]
#   Downloading https://files.pythonhosted.org/packages/d8/f1/5a267addb30ab7eaa1beab2b9323073815da4551076554ecc890a3595ec9/fuzzywuzzy-0.17.0-py2.py3-none-any.whl
# Collecting python-levenshtein>=0.12; extra == "speedup" (from fuzzywuzzy[speedup])
#   Downloading https://files.pythonhosted.org/packages/42/a9/d1785c85ebf9b7dfacd08938dd028209c34a0ea3b1bcdb895208bd40a67d/python-Levenshtein-0.12.0.tar.gz (48kB)
#      |████████████████████████████████| 51kB 3.6MB/s
# Requirement already satisfied: setuptools in /usr/local/lib/python3.6/dist-packages (from python-levenshtein>=0.12; extra == "speedup"->fuzzywuzzy[speedup]) (41.0.1)
# Building wheels for collected packages: python-levenshtein
#   Building wheel for python-levenshtein (setup.py) ... done
#   Stored in directory: /root/.cache/pip/wheels/de/c2/93/660fd5f7559049268ad2dc6d81c4e39e9e36518766eaf7e342
# Successfully built python-levenshtein
# Installing collected packages: python-levenshtein, fuzzywuzzy
# Successfully installed fuzzywuzzy-0.17.0 python-levenshtein-0.12.0

# %%
from fuzzywuzzy import fuzz
fuzz.ratio("pizza", "La pino Pizza")
# Out:
# 56

# %%
import re
from fuzzywuzzy import fuzz

def evaluateString(eachvalue):
#   if KeyWord.lower() in eachvalue.lower():
  
  if fuzz.ratio(KeyWord.lower(), eachvalue.lower())>30:
#   if re.search(KeyWord, eachvalue.lower()):
    return 1
  else:
    return 0

global KeyWord
KeyWord = "piz+a$"
# pizza 
# pizzzzaa
#pizaaaa
#pizzzaaaaaa
#pppppppzaaa
# %time zomato_df['NewValue'] = zomato_df['Restaurant Name'].apply(evaluateString)
zomato_df[zomato_df['NewValue'] == 1]['Restaurant Name']
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-267a00a60366> in <module>()
#       1 import re
# ----> 2 from fuzzywuzzy import fuzz
#       3
#       4 def evaluateString(eachvalue):
#       5 #   if KeyWord.lower() in eachvalue.lower():
#
# ModuleNotFoundError: No module named 'fuzzywuzzy'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
import re
from fuzzywuzzy import fuzz

def evaluateString(eachvalue):
#   if KeyWord.lower() in eachvalue.lower():
    if re.search(KeyWord, eachvalue.lower()):
      return 1
    else:
      return 0

global KeyWord
KeyWord = "piz+e$"
# pizza 
# pizzzzaa
#pizaaaa
#pizzzaaaaaa
#pppppppzaaa
zomato_df['NewValue'] = zomato_df['Restaurant Name'].apply(evaluateString)
zomato_df[zomato_df['NewValue'] == 1]['Restaurant Name']
# Out:
# Series([], Name: Restaurant Name, dtype: object)

# %%
import re
from fuzzywuzzy import fuzz

def evaluateString(eachvalue):
  if KeyWord.lower() in eachvalue.lower():
  
    if fuzz.ratio(KeyWord.lower(), eachvalue.lower())>30:
    if re.search(KeyWord, eachvalue.lower()):
    print('eachvalue')
  else:
    return 0

global KeyWord
KeyWord = "piz+a$"
# pizza 
# pizzzzaa
#pizaaaa
#pizzzaaaaaa
#pppppppzaaa
# %time zomato_df['NewValue'] = zomato_df['Restaurant Name'].apply(evaluateString)
zomato_df[zomato_df['NewValue'] == 1]['Restaurant Name']

# %%
# Logic 
"""
Column with Rest Name 

-> Filter all Names where, it has nothing to do with Pizza
  -> Break the words into tokens 
      --> For each token, check fuzzymatch ratio
            ---> eachToken should be >50
      -->For overall token , ratio can be >30
      
--> Use, IF and Not For 
--> Tried Regex ( String Matching Functionality )
--> Use Apply function on table for each row ( no for loop )




"""

# Code 


# Venkat's Code 
import re
from fuzzywuzzy import fuzz
def findValue(val):
#   if(val.find("pizza")):
    if(re.search("piz+a+[a-z]*$", val.lower()) or (fuzz.ratio("pizza", val.lower()) > 60)) :
      return 1
    else:
      return 0
  
# %time zomato_df["pizzaRest"] = zomato_df["Restaurant Name"].apply(findValue)
zomato_df[zomato_df["pizzaRest"]==1]["Restaurant Name"]
#print (zomato_df[zomato_df['pizzaRest'] == 1]['Restaurant Name'])
# Out:
# CPU times: user 63.4 ms, sys: 1.15 ms, total: 64.6 ms
# Wall time: 70 ms
# 154                       Flying Pie Pizzaria
# 156     Guido's Original New York Style Pizza
# 179                     A & A Pagliai's Pizza
# 217         Tony's Italian Restaurant & Pizza
# 231                    Crust Stone Oven Pizza
# 256                              Fong's Pizza
# 324                   Ingleside Village Pizza
# 477                           Bob Roe's Pizza
# 483                             Jerry's Pizza
# 493                            El Fredo Pizza
# 613                                 Pizza Hut
# 641                                 Pizza Hut
# 648                        Fozzie's Pizzaiolo
# 649                           La Pino'z Pizza
# 657                                  Puffizza
# 674                                 Pizza Hut
# 709                            Domino's Pizza
# 753                                 Pizza Hut
# 757                               Da pizzeria
# 933                             Chicago Pizza
# 1052                           Domino's Pizza
# 1130                           Domino's Pizza
# 1192                           Domino's Pizza
# 1194                                PizzaVito
# 1254                               Instapizza
# 1263                           Domino's Pizza
# 1273                               Instapizza
# 1284                           Domino's Pizza
# 1494                          La Pino'z Pizza
# 1582                            Chicago Pizza
#                         ...
# 8062                             PizzaExpress
# 8098                                Pizza Hut
# 8123                           Domino's Pizza
# 8174                                Pizza Hut
# 8193                            Chicago Pizza
# 8275                           Domino's Pizza
# 8317                           Domino's Pizza
# 8344                                Pizza Key
# 8371                             Cheese Pizza
# 8437                           Domino's Pizza
# 8581                            Mexican Pizza
# 8615                           Domino's Pizza
# 8640                          Ovenstory Pizza
# 8655                            Chicago Pizza
# 8715                           Domino's Pizza
# 8749                           Domino's Pizza
# 8861                           Domino's Pizza
# 8878                                Pizza Hut
# 8987                           Domino's Pizza
# 9039                                Pizza Hut
# 9051                                 US Pizza
# 9059                                Pizza Hut
# 9068                           Domino's Pizza
# 9078                           Domino's Pizza
# 9094                                Pizza Hut
# 9192                                Pizza Hut
# 9210                                Pizza Hut
# 9234                                Pizza Hut
# 9256                                Pizza Hut
# 9257                                Pizza Hut
# Name: Restaurant Name, Length: 194, dtype: object

# %%
import re
from fuzzywuzzy import fuzz
def findValue(val):
    if(re.search("first floor", val.lower()) or (fuzz.ratio("first floor", val.lower()) > 50)) :
      return 1
    else:
      return 0
  
# %time zomato_df["Add_first_floor"] = zomato_df["Address"].apply(findValue)
zomato_df[zomato_df["Add_first_floor"]==1]["Address"]
#print (zomato_df[zomato_df['pizzaRest'] == 1]['Restaurant Name'])
# Out:
# CPU times: user 78.4 ms, sys: 741 µs, total: 79.1 ms
# Wall time: 81.6 ms
# 660     12, First Floor, Camps Corner 2, Opposite Prah...
# 720     First Floor, Bhau Pathak Smriti Kamgar Bhavan,...
# 722     First Floor, Food Court, Prozone Mall, MIDC In...
# 960     SCF 39, First Floor, Above Axis Bank, Sector 1...
# 1289     First Floor, DLF Mega Mall, DLF Phase 1, Gurgaon
# 2317    First Floor, Shilparamam Complex, Opposite Cyb...
# 2340    101, D-46-B,First Floor, Mangalam Ambition Tow...
# 2516    First Floor, Kuvempu Trust Building, Near Chan...
# 2621    D1, First Floor, Abhishek Tower, Alaknanda, Ne...
# 3995      T-49, First Floor, Hauz Khas Village, New Delhi
# 4843         I-54, First Floor, Lajpat Nagar 1, New Delhi
# 6973            295, First Floor, Satyaniketan, New Delhi
# 7081    Shop 48A-51, First Floor, District Centre, Sak...
# 7754    38, Upper Ground Floor & First Floor, Basant L...
# 8245    First Floor, KM-01, Sector 104, Sector 110, Noida
# 8247    A2/11, First Floor, Sector 110 Main Market, Se...
# 8286                 N-199, First Floor, Sector 12, Noida
# 8929                 E-214, First Floor, Sector 63, Noida
# Name: Address, dtype: object
